# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('FMI_data.csv')
# Identify stations with fewer than 96 entries
stations_to_remove = data.groupby('name').filter(lambda x: len(x) < 96)['name'].unique()

# Remove rows for these stations
data = data[~data['name'].isin(stations_to_remove)]

# Convert 'Timestamp' column to datetime
data['Timestamp'] = pd.to_datetime(data['Timestamp'])

# We consider each temperature measurement (=a row in dataframe) as a
# separate data point.

# Get the number of data points and the number of unique stations.
n_stations = len(data.name.unique())
n_datapoints = len(data)

# %%
for i, station in enumerate(data.name.unique()):
    # Extract data of the given station
    station_data = data[data.name==station]
    
    # Extract temperature values and normalize latitude/longitude.
    temps = station_data['temp'].values
    latitudes = station_data['Latitude'].values / 100
    longitudes = station_data['Longitude'].values / 100

    # Extract and normalize time-based features (year, month, day, hour, minute) – Feature Scaling
    timestamps = pd.to_datetime(station_data['Timestamp'])
    year = timestamps.dt.year / 2025
    month = timestamps.dt.month / 13
    day = timestamps.dt.day / 32
    hour = timestamps.dt.hour / 25
    minute = timestamps.dt.minute / 61

    # Combine features into the feature matrix
    X = np.column_stack([latitudes, longitudes, year, month, day, hour, minute])
    y = temps.reshape(-1, 1)

    print(X)
    print(y)
    break
# Out:
# [[0.6904277  0.2085091  0.99901235 0.92307692 0.96875    0.72
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.90625    0.68
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.9375     0.84
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.9375     0.32
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.875      0.6
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.9375     0.12
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.875      0.84
#   0.        ]
#  [0.6904277  0.2085091  0.99950617 0.07692308 0.03125    0.12
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.96875    0.8
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.96875    0.68
#   0.        ]
#  [0.6904277  0.2085091  0.99950617 0.07692308 0.03125    0.36
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.90625    0.56
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.90625    0.
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.96875    0.16
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.90625    0.08
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.96875    0.
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.96875    0.56
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.875      0.8
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.90625    0.36
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.875      0.44
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.96875    0.88
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.90625    0.8
#   0.        ]
#  [0.6904277  0.2085091  0.99950617 0.07692308 0.03125    0.08
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.9375     0.28
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.90625    0.72
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.9375     0.36
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.90625    0.64
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.96875    0.28
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.9375     0.88
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.875      0.56
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.90625    0.32
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.96875    0.92
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.96875    0.24
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.96875    0.36
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.875      0.72
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.9375     0.6
#   0.        ]
#  [0.6904277  0.2085091  0.99950617 0.07692308 0.03125    0.
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.9375     0.76
#   0.        ]
#  [0.6904277  0.2085091  0.99950617 0.07692308 0.03125    0.32
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.90625    0.2
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.875      0.88
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.875      0.64
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.875      0.92
#   0.        ]
#  [0.6904277  0.2085091  0.99950617 0.07692308 0.03125    0.16
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.9375     0.2
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.90625    0.44
#   0.        ]
#  [0.6904277  0.2085091  0.99950617 0.07692308 0.03125    0.04
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.9375     0.44
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.9375     0.68
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.96875    0.64
#   0.        ]
#  [0.6904277  0.2085091  0.99950617 0.07692308 0.03125    0.2
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.96875    0.48
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.90625    0.4
#   0.        ]
#  [0.6904277  0.2085091  0.99950617 0.07692308 0.03125    0.4
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.9375     0.
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.96875    0.4
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.9375     0.16
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.96875    0.04
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.96875    0.52
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.9375     0.04
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.9375     0.92
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.9375     0.72
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.9375     0.4
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.96875    0.84
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.90625    0.28
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.96875    0.44
#   0.        ]
#  [0.6904277  0.2085091  0.99950617 0.07692308 0.03125    0.24
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.90625    0.92
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.90625    0.84
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.90625    0.76
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.875      0.52
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.90625    0.48
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.90625    0.04
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.90625    0.88
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.96875    0.12
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.875      0.76
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.9375     0.56
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.9375     0.48
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.90625    0.12
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.96875    0.2
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.875      0.68
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.875      0.48
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.96875    0.76
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.9375     0.8
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.96875    0.6
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.9375     0.08
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.96875    0.32
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.90625    0.6
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.9375     0.24
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.90625    0.16
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.96875    0.08
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.9375     0.64
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.90625    0.24
#   0.        ]
#  [0.6904277  0.2085091  0.99950617 0.07692308 0.03125    0.28
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.9375     0.52
#   0.        ]
#  [0.6904277  0.2085091  0.99901235 0.92307692 0.90625    0.52
#   0.        ]]
# [[-16.5]
#  [-12.9]
#  [-16.4]
#  [-15.6]
#  [ -8.1]
#  [-15.1]
#  [ -9. ]
#  [-16.9]
#  [-16.1]
#  [-16.6]
#  [-15.8]
#  [-12.5]
#  [ -9.5]
#  [-16.7]
#  [ -9.7]
#  [-16.5]
#  [-16.6]
#  [ -8.7]
#  [-11.2]
#  [ -7.9]
#  [-16.6]
#  [-13.3]
#  [-17. ]
#  [-15.3]
#  [-12.9]
#  [-16. ]
#  [-12.9]
#  [-16.5]
#  [-16.4]
#  [ -8. ]
#  [-11. ]
#  [-16.8]
#  [-16.6]
#  [-16.3]
#  [ -8.3]
#  [-16.7]
#  [-16.9]
#  [-16.9]
#  [-16.1]
#  [-10.1]
#  [ -9.1]
#  [ -8.2]
#  [ -9.3]
#  [-16.6]
#  [-15. ]
#  [-11.4]
#  [-17. ]
#  [-16.2]
#  [-17. ]
#  [-16.6]
#  [-16.5]
#  [-16.5]
#  [-11.2]
#  [-15.7]
#  [-14.3]
#  [-16.3]
#  [-15.2]
#  [-16.5]
#  [-16.6]
#  [-14.4]
#  [-16.5]
#  [-17.2]
#  [-16.2]
#  [-16.3]
#  [-10.6]
#  [-16.4]
#  [-16.4]
#  [-14.2]
#  [-14.4]
#  [-13. ]
#  [ -8. ]
#  [-11.8]
#  [ -9.7]
#  [-14.2]
#  [-16.7]
#  [ -8.5]
#  [-16.6]
#  [-16.3]
#  [ -9.8]
#  [-16.6]
#  [ -8.3]
#  [ -7.9]
#  [-16.2]
#  [-16.6]
#  [-16.6]
#  [-14.9]
#  [-16.4]
#  [-12.8]
#  [-15.2]
#  [ -9.9]
#  [-16.5]
#  [-16.8]
#  [-10.3]
#  [-16.3]
#  [-16.5]
#  [-12.2]]

# %%
X[0:1, 0:2]
# Out:
# array([[0.6904277, 0.2085091]])

# %%
# Initialize an empty list to hold all datapoints
datapoints = []

# Loop to create 95 datapoints
for i in range(95):
    # Create a feature vector with 203 random features (e.g., floats)
    features = np.random.rand(203)  # shape: (203,)
    # Create an associated label (here, as an integer example)
    label = np.random.randint(0, 10)
    # Append a two-element list [features, label] to the datapoints list
    datapoints.append([features, label])

# Sanity check as provided:
assert np.shape(datapoints) == (95, 2), "The shape of the datapoints list is incorrect."
assert np.all([np.shape(datapoints[i][0]) == (203,) for i in range(len(datapoints))]), "Each datapoint should have 203 features."

print('Sanity check passed!')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/.venv/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:2161, in shape(a)
#    2160 try:
# -> 2161     result = a.shape
#    2162 except AttributeError:
#
# AttributeError: 'list' object has no attribute 'shape'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 14
#      11     datapoints.append([features, label])
#      13 # Sanity check as provided:
# ---> 14 assert np.shape(datapoints) == (95, 2), "The shape of the datapoints list is incorrect."
#      15 assert np.all([np.shape(datapoints[i][0]) == (203,) for i in range(len(datapoints))]), "Each datapoint should have 203 features."
#      17 print('Sanity check passed!')
#
# File ~/.venv/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:2163, in shape(a)
#    2161     result = a.shape
#    2162 except AttributeError:
# -> 2163     result = asarray(a).shape
#    2164 return result
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (95, 2) + inhomogeneous part.

# %%
# Sanity checks

# Check if the shape of datapoints list is correct
assert np.shape(datapoints) == (95, 2), "The shape of the datapoints list is incorrect."
assert np.all([np.shape(datapoints[i][0]) == (203,) for i in range(len(datapoints))]), "Each datapoint should have 203 features."

print('Sanity check passed!')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/.venv/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:2161, in shape(a)
#    2160 try:
# -> 2161     result = a.shape
#    2162 except AttributeError:
#
# AttributeError: 'list' object has no attribute 'shape'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 4
#       1 # Sanity checks
#       2
#       3 # Check if the shape of datapoints list is correct
# ----> 4 assert np.shape(datapoints) == (95, 2), "The shape of the datapoints list is incorrect."
#       5 assert np.all([np.shape(datapoints[i][0]) == (203,) for i in range(len(datapoints))]), "Each datapoint should have 203 features."
#       7 print('Sanity check passed!')
#
# File ~/.venv/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:2163, in shape(a)
#    2161     result = a.shape
#    2162 except AttributeError:
# -> 2163     result = asarray(a).shape
#    2164 return result
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (2, 2) + inhomogeneous part.

# %%
import numpy as np

# Create a list of datapoints
datapoints = []
for i in range(95):
    # Create a feature vector with 203 random numbers
    features = np.random.rand(203)  # NumPy array of shape (203,)
    # Create an associated label (here as an integer)
    label = np.random.randint(0, 10)
    # Each datapoint is a list of two elements: [features, label]
    datapoints.append([features, label])

# This check works using np.shape function (not the .shape attribute)
assert np.shape(datapoints) == (95, 2), "The shape of the datapoints list is incorrect."
assert np.all([np.shape(datapoints[i][0]) == (203,) for i in range(len(datapoints))]), "Each datapoint should have 203 features."

print('Sanity check passed!')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/.venv/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:2161, in shape(a)
#    2160 try:
# -> 2161     result = a.shape
#    2162 except AttributeError:
#
# AttributeError: 'list' object has no attribute 'shape'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 14
#      11     datapoints.append([features, label])
#      13 # This check works using np.shape function (not the .shape attribute)
# ---> 14 assert np.shape(datapoints) == (95, 2), "The shape of the datapoints list is incorrect."
#      15 assert np.all([np.shape(datapoints[i][0]) == (203,) for i in range(len(datapoints))]), "Each datapoint should have 203 features."
#      17 print('Sanity check passed!')
#
# File ~/.venv/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:2163, in shape(a)
#    2161     result = a.shape
#    2162 except AttributeError:
# -> 2163     result = asarray(a).shape
#    2164 return result
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (95, 2) + inhomogeneous part.
